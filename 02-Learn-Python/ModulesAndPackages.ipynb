# %% [markdown]
# # Module and package
# Module: python file, define functions, classes, variable, et, import

# %%
import math

# %%
print(math.sqrt(16))
# Out:
# 4.0

# %% [markdown]
# Install pandas package

# %%
# !pip install pandas

# %%
import pandas as pd
data = {'name': ['John', 'Anna', 'Peter'], 'Age': [20, 30, 40]}
df = pd.DataFrame(data)
print(df)
# Out:
#     name  Age
# 0   John   20
# 1   Anna   30
# 2  Peter   40

# %%
import pandas as pd
data = {'Name': ['James', 'John', 'Jonathan', 'Hagin'], 'Age': [20, 5, 3, 4], 'Address': ['Toronto', 'London', 'North View', 'North York']}
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age     Address
# 0     James   20     Toronto
# 1      John    5      London
# 2  Jonathan    3  North View
# 3     Hagin    4  North York
