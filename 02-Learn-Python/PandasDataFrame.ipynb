# %% [markdown]
# # Pandas
# 1. Open-source data manipulation and analysis library
# 2. Boost data analysis capacities of python
# 3. Can load, prepare, manipulate, model and analyze data
#
# ## What pandas offers:
# 1. Multiple types of data file handling. Read csv, json,html
# 2. Sorting and filtering data
# 3. Mathematical calculations
# 4. Error detection and correction
# 5. Data combination and transformation capabilities
#
# ## Functions of pandas:
# 1. Pandas bridges raw data and insight analysis
# 2. Organizes, cleans and prepare data effortlessly
#
# ## Read files as DataFrame:
# 1. Two dimensional data structure
# 2. Like a table with rows and columns

# %%
# Pandas
import pandas as pd

df = pd.read_csv('/content/Order.csv')

print(df) #

# %%
# To read all dataframe
print(df.to_string)

# %%
# for IoT, JSON

import pandas as pd

df = pd.read_json('/content/sample_data/anscombe.json')

print(df)

# %%
from os import path
df = pd.read_excel('\file_path')
